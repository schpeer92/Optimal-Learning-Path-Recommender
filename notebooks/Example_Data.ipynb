# %%
import pandas as pd
import bnlearn as bn
import gekko as gk

# %%
df = bn.import_example('sachs')
# Out:
# [bnlearn] >Downloading example [sachs] dataset..
# 100% [..............................................................................] 21822 / 21822[bnlearn] >Extracting files..
# Exception ignored in: <function tqdm.__del__ at 0x7fcb21130c10>
# Traceback (most recent call last):
#   File "/mnt/d/Python/Projects/optimal_learning_path/.env/lib/python3.8/site-packages/tqdm/std.py", line 1147, in __del__
#     self.close()
#   File "/mnt/d/Python/Projects/optimal_learning_path/.env/lib/python3.8/site-packages/tqdm/notebook.py", line 286, in close
#     self.disp(bar_style='danger', check_delay=False)
# AttributeError: 'tqdm' object has no attribute 'disp'
# [bnlearn] >Warning: CPD [Akt] does not add up to 1 but is: [[1.         1.         1.        ]
#  [1.         1.         0.99999998]
#  [0.99999992 1.         1.        ]]
# [bnlearn] >Warning: CPD [Erk] does not add up to 1 but is: [[1.         1.         1.        ]
#  [1.         1.         1.        ]
# ...

# %%
G = bn.plot(model)
# Out:
# [bnlearn]> Set node properties.
# [bnlearn] >Plot based on BayesianModel

# %%
DAG = bn.import_DAG('../data/zip/cancer.bif')
# Out:
# [bnlearn] >Import <../data/zip/cancer.bif>
# [bnlearn] >Loading bif file <../data/zip/cancer.bif>
# [bnlearn] >Checking CPDs..
# [bnlearn] >Check for DAG structure. Correct: True

# %%
bn.plot(DAG)
# Out:
# [bnlearn]> Set node properties.
# [bnlearn] >Plot based on BayesianModel
# {'pos': {'Pollution': array([ 0.45349946, -0.83604107]),
#   'Cancer': array([0.18024428, 1.        ]),
#   'Smoker': array([0.78934291, 0.12723443]),
#   'Xray': array([-0.66124419, -0.75159483]),
#   'Dyspnoea': array([-0.76184245,  0.46040147])},
#  'G': <networkx.classes.digraph.DiGraph at 0x7fcabe6afc70>,
#  'node_properties': {'Pollution': {'node_color': '#1f456e', 'node_size': 800},
#   'Cancer': {'node_color': '#1f456e', 'node_size': 800},
#   'Smoker': {'node_color': '#1f456e', 'node_size': 800},
#   'Xray': {'node_color': '#1f456e', 'node_size': 800},
#   'Dyspnoea': {'node_color': '#1f456e', 'node_size': 800}}}
